# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Dataset/AirQuality.csv",sep=';', decimal=',')

df.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# ...

# %%
df = df.iloc[:, :-2]

# %%
print(df.shape)
print(df.columns)
# Out:
# (9471, 15)
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH'],
#       dtype='object')

# %%
df.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %%
print("\nData types:")
print(df.dtypes)
# Out:
# Data types:
# Date              object
# Time              object
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# dtype: object

# %%
print("\nDataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
# dtypes: float64(13), object(2)
# memory usage: 1.1+ MB

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Date             114
# Time             114
# CO(GT)           114
# PT08.S1(CO)      114
# NMHC(GT)         114
# C6H6(GT)         114
# PT08.S2(NMHC)    114
# NOx(GT)          114
# PT08.S3(NOx)     114
# NO2(GT)          114
# PT08.S4(NO2)     114
# PT08.S5(O3)      114
# T                114
# RH               114
# AH               114
# dtype: int64

# %% [markdown]
# # Missing values are tagged with -200 value. from the dataset description

# %%
print("Count of -200 values in each column:")
print((df == -200).sum())
# Out:
# Count of -200 values in each column:
# Date                0
# Time                0
# CO(GT)           1683
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64

# %%
import numpy as np

df.replace(-200, np.nan, inplace=True)

# %%
missing_percentage = df.isnull().mean() * 100
print(missing_percentage.sort_values(ascending=False))
# Out:
# NMHC(GT)         90.349488
# CO(GT)           18.973709
# NO2(GT)          18.540809
# NOx(GT)          18.509133
# PT08.S2(NMHC)     5.068103
# C6H6(GT)          5.068103
# PT08.S1(CO)       5.068103
# PT08.S5(O3)       5.068103
# T                 5.068103
# PT08.S3(NOx)      5.068103
# PT08.S4(NO2)      5.068103
# RH                5.068103
# AH                5.068103
# Date              1.203674
# Time              1.203674
# dtype: float64

# %% [markdown]
# # dropping the NMHC COl

# %%
df.drop(columns=['NMHC(GT)'], inplace=True)

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Date              114
# Time              114
# CO(GT)           1797
# PT08.S1(CO)       480
# C6H6(GT)          480
# PT08.S2(NMHC)     480
# NOx(GT)          1753
# PT08.S3(NOx)      480
# NO2(GT)          1756
# PT08.S4(NO2)      480
# PT08.S5(O3)       480
# T                 480
# RH                480
# AH                480
# dtype: int64

# %% [markdown]
# # dropping the rows where CO is missing

# %%
df = df.dropna(subset=['CO(GT)'])

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Date               0
# Time               0
# CO(GT)             0
# PT08.S1(CO)      330
# C6H6(GT)         330
# PT08.S2(NMHC)    330
# NOx(GT)          413
# PT08.S3(NOx)     330
# NO2(GT)          416
# PT08.S4(NO2)     330
# PT08.S5(O3)      330
# T                330
# RH               330
# AH               330
# dtype: int64

# %% [markdown]
# # the missing value is too small so dropping it

# %%
df = df.dropna()

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
print(df.shape)
# Out:
# (6941, 14)

# %%
df['Datetime'] = pd.to_datetime(
    df['Date'] + ' ' + df['Time'],
    format='%d/%m/%Y %H.%M.%S'
)

df = df.sort_values('Datetime')
df.set_index('Datetime', inplace=True)

# %% [markdown]
# ## Plottings to get better understanding of the dataset

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
plt.plot(df['CO(GT)'])
plt.title("CO(GT) Over Time")
plt.xlabel("Time")
plt.ylabel("CO Concentration")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(6,4))
sns.histplot(df['CO(GT)'], kde=True)
plt.title("Distribution of CO(GT)")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['CO(GT)'])
plt.title("Boxplot of CO(GT)")
plt.show()

# %%
numeric_df = df.select_dtypes(include=['number'])

plt.figure(figsize=(10,8))
sns.heatmap(numeric_df.corr(), cmap='coolwarm')
plt.title("Feature Correlation Matrix")
plt.show()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # Lag Feature

# %%
df['CO_lag1'] = df['CO(GT)'].shift(1)
df['CO_lag2'] = df['CO(GT)'].shift(2)
df['CO_lag3'] = df['CO(GT)'].shift(3)

# %% [markdown]
# # Rolling Mean

# %%
df['CO_roll3'] = df['CO(GT)'].rolling(3).mean()

# %% [markdown]
# # Time Features

# %%
df['hour'] = df.index.hour
df['dayofweek'] = df.index.dayofweek
df['month'] = df.index.month

# %%
print(df.shape)
print(df.columns)
# Out:
# (6941, 21)
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'C6H6(GT)', 'PT08.S2(NMHC)',
#        'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)',
#        'T', 'RH', 'AH', 'CO_lag1', 'CO_lag2', 'CO_lag3', 'CO_roll3', 'hour',
#        'dayofweek', 'month'],
#       dtype='object')

# %%
df.head()
# Out:
#                            Date      Time  CO(GT)  PT08.S1(CO)  C6H6(GT)  \
# Datetime
# 2004-03-10 18:00:00  10/03/2004  18.00.00     2.6       1360.0      11.9
# 2004-03-10 19:00:00  10/03/2004  19.00.00     2.0       1292.0       9.4
# 2004-03-10 20:00:00  10/03/2004  20.00.00     2.2       1402.0       9.0
# 2004-03-10 21:00:00  10/03/2004  21.00.00     2.2       1376.0       9.2
# 2004-03-10 22:00:00  10/03/2004  22.00.00     1.6       1272.0       6.5
#
#                      PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  \
# Datetime
# 2004-03-10 18:00:00         1046.0    166.0        1056.0    113.0
# 2004-03-10 19:00:00          955.0    103.0        1174.0     92.0
# 2004-03-10 20:00:00          939.0    131.0        1140.0    114.0
# 2004-03-10 21:00:00          948.0    172.0        1092.0    122.0
# 2004-03-10 22:00:00          836.0    131.0        1205.0    116.0
#
#                      PT08.S4(NO2)  ...     T    RH      AH  CO_lag1  CO_lag2  \
# ...

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# CO_lag1          1
# CO_lag2          2
# CO_lag3          3
# CO_roll3         2
# hour             0
# dayofweek        0
# month            0
# dtype: int64

# %%
df = df.dropna()

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# CO_lag1          0
# CO_lag2          0
# CO_lag3          0
# CO_roll3         0
# hour             0
# dayofweek        0
# month            0
# dtype: int64

# %%
df['CO_next'] = df['CO(GT)'].shift(-1)
# Out:
# /tmp/ipykernel_705/3446471231.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CO_next'] = df['CO(GT)'].shift(-1)

# %%
df = df.dropna()

# %%
df.drop(columns=['Date', 'Time'], inplace=True)
# Out:
# /tmp/ipykernel_705/578786804.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Date', 'Time'], inplace=True)

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# CO(GT)           0
# PT08.S1(CO)      0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# CO_lag1          0
# CO_lag2          0
# CO_lag3          0
# CO_roll3         0
# hour             0
# dayofweek        0
# month            0
# CO_next          0
# dtype: int64

# %% [markdown]
# # x,y split

# %%
y = df['CO_next']

# %%
X = df.drop(columns=['CO_next'])

# %%
split_index = int(len(df) * 0.8)

X_train = X.iloc[:split_index]
X_test = X.iloc[split_index:]

y_train = y.iloc[:split_index]
y_test = y.iloc[split_index:]

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (6937, 19)
# y shape: (6937,)

# %%
print("Target column:")
print(y.name)
# Out:
# Target column:
# CO_next

# %%
print("Feature columns:")
print(X.columns.tolist())
# Out:
# Feature columns:
# ['CO(GT)', 'PT08.S1(CO)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH', 'CO_lag1', 'CO_lag2', 'CO_lag3', 'CO_roll3', 'hour', 'dayofweek', 'month']

# %%
df['CO(GT)'].describe()
# Out:
# count    6937.000000
# mean        2.182428
# std         1.441563
# min         0.100000
# 25%         1.100000
# 50%         1.900000
# 75%         2.900000
# max        11.900000
# Name: CO(GT), dtype: float64

# %% [markdown]
# # Model Training : Will trail 5 model and campare them

# %%
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Ridge": Ridge(),
    "Random Forest": RandomForestRegressor(n_estimators=100, random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(n_estimators=100, random_state=42),
    "XGBoost": XGBRegressor(n_estimators=100, random_state=42, verbosity=0)
}

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import pandas as pd

results = []

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))

    results.append({
        "Model": name,
        "MAE": mae,
        "RMSE": rmse
    })

results_df = pd.DataFrame(results)
results_df.sort_values(by="RMSE")
# Out:
#                Model       MAE      RMSE
# 3  Gradient Boosting  0.414443  0.589615
# 2      Random Forest  0.418162  0.593495
# 4            XGBoost  0.412268  0.598039
# 1              Ridge  0.456443  0.667497
# 0  Linear Regression  0.456490  0.667519

# %%
best_model_name = results_df.sort_values(by="RMSE").iloc[0]["Model"]
best_model = models[best_model_name]

print("Best Model:", best_model_name)
# Out:
# Best Model: Gradient Boosting

# %% [markdown]
# **Visualization**

# %%
y_pred_best = best_model.predict(X_test)

import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
plt.plot(y_test.values, label="Actual", alpha=0.7)
plt.plot(y_pred_best, label="Predicted", alpha=0.7)
plt.title(f"Actual vs Predicted CO (Next Hour)\nBest Model: {best_model_name}")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(y_test.values[:300], label="Actual")
plt.plot(y_pred_best[:300], label="Predicted")
plt.title(f"Zoomed View - First 300 Test Points\nBest Model: {best_model_name}")
plt.legend()
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8,5))
sns.barplot(data=results_df, x="Model", y="RMSE")
plt.xticks(rotation=45)
plt.title("Model Comparison (RMSE)")
plt.show()
